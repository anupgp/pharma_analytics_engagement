# %%
import sys
sys.path.append('../')
from src.data_ingestion import MedicalDataIngestor
from src.sales_ops import SalesOpsAnalyzer

# 1. Initialize API Engine and fetch live data
ingestor = MedicalDataIngestor(config_path='../config/config.yaml')
df_live = ingestor.fetch_via_api(limit=10000) # Grabs first 10k live records cleanly

# 2. Run Market Share Strategy on the molecule family (e.g., Aripiprazole from your data sample)
analyzer = SalesOpsAnalyzer(ingestor.config['cms_schema'])
market_insights = analyzer.compute_therapeutic_market_share(df_live, "Aripiprazole")

market_insights.head()
# Out:
# 2026-06-07 20:10:42,730 - INFO - Initiating dynamic connection to CMS Open Data API...
# 2026-06-07 20:10:43,084 - INFO - API Streaming successful. Fetched 6500 live records.
# 2026-06-07 20:10:43,095 - INFO - Filtering dataset for molecular class signal: Aripiprazole
# 2026-06-07 20:10:43,102 - INFO - Regional market intelligence parameters successfully calculated.
#   Prscrbr_Geo_Desc          Brnd_Name  Tot_Clms  Total_Class_Claims  \
# 3          Alabama       Aripiprazole     62189               68734
# 2          Alabama   Abilify Maintena      5935               68734
# 4          Alabama   Aripiprazole Odt       315               68734
# 1          Alabama  Abilify Asimtufii       261               68734
# 0          Alabama            Abilify        34               68734
#
#    Market_Share_Pct
# 3         90.477784
# 2          8.634737
# 4          0.458288
# 1          0.379725
# 0          0.049466
